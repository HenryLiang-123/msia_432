# %% [markdown]
# # MNIST CNN
#
# Trains a simple convnet on the MNIST dataset. Gets to 99.25% test accuracy after 12 epochs with plenty of margin for parameter tuning. This takes 16 seconds per epoch on a GRID K520 GPU and 19 seconds on GTX 1060.

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (7,7)
# %matplotlib inline

import tensorflow
import keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten,BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from tensorflow.keras import backend as K

# %%
batch_size = 128
num_classes = 10
epochs = 50

# input image dimensions
img_rows, img_cols = 28, 28

# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %% [markdown]
# ## Format data for training
# Our neural-network does not need a single 784 dimensional vector. However,we'll scale the inputs to be in the range [0-1] rather than [0-255]

# %%
if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = tensorflow.keras.utils.to_categorical(y_train, num_classes)
y_test = tensorflow.keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ## Build the CNN
#
# Regularization - BatchNormalization and Dropouts are optional

# %%
#Using Keras Sequential API
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  batch_normalization_1 (Batc  (None, 26, 26, 32)       128
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 12, 12, 64)        0
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_2 (Dense)             (None, 128)               1179776
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1,200,010
# Trainable params: 1,199,946
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# ## Compile the model
# Keras is using TensorFlow as a backend.
#
# When compiling a model, Keras asks you to specify your **loss function** and your **optimizer**. The loss function we'll use here is called *categorical crossentropy*, and is a loss function well-suited to comparing two probability distributions.

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=tensorflow.keras.optimizers.Adadelta(),
              metrics=['accuracy'])

# %% [markdown]
# ## Callbacks
#
#
# [EarlyStopping](https://keras.io/api/callbacks/early_stopping/) Stop training when a monitored metric has stopped improving.
#
# [ModelCheckpoint](https://keras.io/api/callbacks/model_checkpoint/) callback is used in conjunction with training using model.fit() to save a model or weights (in a checkpoint file) at some interval, so the model or weights can be loaded later to continue the training from the state saved.

# %%
my_callbacks = [
    EarlyStopping(patience=3),
    TensorBoard(log_dir='logs'),
]

# %% [markdown]
# ## Train Model
# Feed the training data loaded in earlier into this model and it will learn to classify digits

# %%
history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test),
          callbacks=my_callbacks)
# Out:
# Epoch 1/50
# 2023-04-26 20:39:57.286535: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_1/dropout_2/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 469/469 [==============================] - 4s 7ms/step - loss: 2.3200 - accuracy: 0.1948 - val_loss: 1.9226 - val_accuracy: 0.5781
# Epoch 2/50
# 469/469 [==============================] - 4s 8ms/step - loss: 1.7734 - accuracy: 0.3918 - val_loss: 1.2960 - val_accuracy: 0.7350
# Epoch 3/50
# 469/469 [==============================] - 4s 8ms/step - loss: 1.4715 - accuracy: 0.5183 - val_loss: 1.0035 - val_accuracy: 0.7940
# Epoch 4/50
# 469/469 [==============================] - 4s 9ms/step - loss: 1.2507 - accuracy: 0.5965 - val_loss: 0.8107 - val_accuracy: 0.8267
# Epoch 5/50
# 469/469 [==============================] - 4s 9ms/step - loss: 1.0917 - accuracy: 0.6520 - val_loss: 0.6790 - val_accuracy: 0.8486
# Epoch 6/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.9726 - accuracy: 0.6911 - val_loss: 0.5892 - val_accuracy: 0.8635
# Epoch 7/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.8822 - accuracy: 0.7188 - val_loss: 0.5240 - val_accuracy: 0.8763
# Epoch 8/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.8175 - accuracy: 0.7416 - val_loss: 0.4762 - val_accuracy: 0.8855
# Epoch 9/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.7642 - accuracy: 0.7613 - val_loss: 0.4390 - val_accuracy: 0.8931
# Epoch 10/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.7176 - accuracy: 0.7711 - val_loss: 0.4088 - val_accuracy: 0.9000
# Epoch 11/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.6761 - accuracy: 0.7889 - val_loss: 0.3835 - val_accuracy: 0.9065
# Epoch 12/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.6400 - accuracy: 0.7980 - val_loss: 0.3636 - val_accuracy: 0.9090
# Epoch 13/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.6143 - accuracy: 0.8091 - val_loss: 0.3456 - val_accuracy: 0.9133
# Epoch 14/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.5892 - accuracy: 0.8159 - val_loss: 0.3306 - val_accuracy: 0.9162
# Epoch 15/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.5668 - accuracy: 0.8231 - val_loss: 0.3174 - val_accuracy: 0.9191
# Epoch 16/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.5440 - accuracy: 0.8304 - val_loss: 0.3049 - val_accuracy: 0.9209
# Epoch 17/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.5298 - accuracy: 0.8343 - val_loss: 0.2945 - val_accuracy: 0.9227
# Epoch 18/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.5081 - accuracy: 0.8439 - val_loss: 0.2848 - val_accuracy: 0.9257
# Epoch 19/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.4967 - accuracy: 0.8459 - val_loss: 0.2758 - val_accuracy: 0.9286
# Epoch 20/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.4839 - accuracy: 0.8505 - val_loss: 0.2676 - val_accuracy: 0.9306
# Epoch 21/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4719 - accuracy: 0.8556 - val_loss: 0.2613 - val_accuracy: 0.9318
# Epoch 22/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4563 - accuracy: 0.8597 - val_loss: 0.2539 - val_accuracy: 0.9326
# Epoch 23/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4458 - accuracy: 0.8645 - val_loss: 0.2468 - val_accuracy: 0.9345
# Epoch 24/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4359 - accuracy: 0.8668 - val_loss: 0.2413 - val_accuracy: 0.9358
# Epoch 25/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.4253 - accuracy: 0.8708 - val_loss: 0.2357 - val_accuracy: 0.9364
# Epoch 26/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.4179 - accuracy: 0.8722 - val_loss: 0.2306 - val_accuracy: 0.9377
# Epoch 27/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4089 - accuracy: 0.8759 - val_loss: 0.2253 - val_accuracy: 0.9388
# Epoch 28/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4018 - accuracy: 0.8774 - val_loss: 0.2207 - val_accuracy: 0.9394
# Epoch 29/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3931 - accuracy: 0.8806 - val_loss: 0.2159 - val_accuracy: 0.9411
# Epoch 30/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3828 - accuracy: 0.8832 - val_loss: 0.2119 - val_accuracy: 0.9419
# Epoch 31/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3770 - accuracy: 0.8857 - val_loss: 0.2072 - val_accuracy: 0.9431
# Epoch 32/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3709 - accuracy: 0.8872 - val_loss: 0.2036 - val_accuracy: 0.9438
# Epoch 33/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3643 - accuracy: 0.8903 - val_loss: 0.1997 - val_accuracy: 0.9448
# Epoch 34/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3582 - accuracy: 0.8925 - val_loss: 0.1963 - val_accuracy: 0.9456
# Epoch 35/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3521 - accuracy: 0.8943 - val_loss: 0.1927 - val_accuracy: 0.9457
# Epoch 36/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3448 - accuracy: 0.8954 - val_loss: 0.1893 - val_accuracy: 0.9461
# Epoch 37/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3446 - accuracy: 0.8976 - val_loss: 0.1860 - val_accuracy: 0.9472
# Epoch 38/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3361 - accuracy: 0.8990 - val_loss: 0.1827 - val_accuracy: 0.9481
# Epoch 39/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3286 - accuracy: 0.9017 - val_loss: 0.1799 - val_accuracy: 0.9491
# Epoch 40/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3236 - accuracy: 0.9031 - val_loss: 0.1768 - val_accuracy: 0.9503
# Epoch 41/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3213 - accuracy: 0.9038 - val_loss: 0.1740 - val_accuracy: 0.9503
# Epoch 42/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3188 - accuracy: 0.9041 - val_loss: 0.1712 - val_accuracy: 0.9509
# Epoch 43/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3100 - accuracy: 0.9062 - val_loss: 0.1689 - val_accuracy: 0.9517
# Epoch 44/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3083 - accuracy: 0.9080 - val_loss: 0.1663 - val_accuracy: 0.9525
# Epoch 45/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2998 - accuracy: 0.9097 - val_loss: 0.1638 - val_accuracy: 0.9528
# Epoch 46/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2992 - accuracy: 0.9102 - val_loss: 0.1614 - val_accuracy: 0.9535
# Epoch 47/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2937 - accuracy: 0.9130 - val_loss: 0.1590 - val_accuracy: 0.9538
# Epoch 48/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2882 - accuracy: 0.9148 - val_loss: 0.1566 - val_accuracy: 0.9551
# Epoch 49/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2846 - accuracy: 0.9141 - val_loss: 0.1542 - val_accuracy: 0.9556
# Epoch 50/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2828 - accuracy: 0.9151 - val_loss: 0.1522 - val_accuracy: 0.9567

# %% [markdown]
# ## Evaluate performance

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score)
# Out:
# Test loss: [0.15216118097305298, 0.9567000269889832]

# %% [markdown]
# ## Loss curve

# %%
plt.figure(figsize=[6,4])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Loss Curves')

# %% [markdown]
# ## Inspect the output
#
# Inspect the output and look at some examples it gets right, and some examples it gets wrong. The predict_classes function outputs the highest probability class according to the trained classifier for each input example.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
predicted_classes = np.argmax(model.predict(x_test), axis=-1)

#print(predicted_classes)

# Check which items we got right / wrong
correct_indices = np.nonzero(predicted_classes == y_test)[0]
incorrect_indices = np.nonzero(predicted_classes != y_test)[0]

#print(correct_indices)
#print(incorrect_indices)
# Out:
# 313/313 [==============================] - 0s 749us/step

# %%
#some of the correct results
plt.figure(figsize=(8,8))
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(x_test[correct].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[correct], y_test[correct]))
    
#some of the incorrect predictions
plt.figure(figsize=(8,8))
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(x_test[incorrect].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[incorrect], y_test[incorrect]))

# %% [markdown]
# ## <span style="color:cornflowerblue">Exercise:</span>

# %% [markdown]
# <font color="red">Exercise: Improve the accuracy score of the CNN by :
#     1 ) adding more layers 2) hyperparameter optimization</font>
